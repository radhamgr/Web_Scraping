# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
seed_urls = ['https://inshorts.com/en/read/sports',
             'https://inshorts.com/en/read/technology',
             'https://inshorts.com/en/read/world']
def build_dataset(seed_urls):
    news_data = []
    for url in seed_urls:
        news_category = url.split('/')[-1]
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        
        news_articles = [{'news_headline': headline.find('span', 
                                                         attrs = {"itemprop": "headline"}).string,
                          'news_article': article.find('div', 
                                                       attrs ={"itemprop": "articleBody"}).string,
                          'news_category': news_category}
                            for headline,article in 
                             zip(soup.find_all('div', 
                                               {'class':"news-card-title news-right-box"}),
                                  soup.find_all('div', 
                                                {'class':"news-card-content news-right-box"}))
                        ]
        news_data.extend(news_articles)
    df = pd.DataFrame(news_data)
    df = df[['news_headline','news_article','news_category']]
    return df

# %%
news_df = build_dataset(seed_urls)
news_df
# Out:
#                                         news_headline  \
# 0   Kohli replies 'Thanks Bhavesh' to Raina's birt...
# 1   Ajinkya Rahane shares first picture of his new...
# 2   India-Pakistan Davis Cup tie shifted to neutra...
# 3   Third umpire should be able to spot no-balls, ...
# 4   Every time Kohli takes a break, his void gets ...
# ..                                                ...
# 69  25,000 S Koreans fake death by lying in coffin...
# 70       US Congresswoman Ilhan Omar divorces husband
# 71  ISIS attempted suicide attack in India last ye...
# 72  Hong Kong politician stabbed in chest during a...
# 73  Malaysia sentences 5 men to jail for attemptin...
#
#                                          news_article news_category
# 0   Team India captain Virat Kohli was trolled on ...        sports
# 1   Team India Test vice-captain Ajinkya Rahane to...        sports
# 2   The Davis Cup tie between India and Pakistan h...        sports
# 3   Former Australia wicketkeeper-batsman Adam Gil...        sports
# 4   Former India all-rounder Mohinder Amarnath has...        sports
# ..                                                ...           ...
# 69  Over 25,000 South Koreans have reportedly simu...         world
# 70  US Congresswoman from Minnesota Ilhan Omar div...         world
# 71  The Khorasan group of the Islamic State (ISIS-...         world
# 72  Hong Kong politician Junius Ho was stabbed by ...         world
# 73  A Malaysian religious court on Thursday fined ...         world
#
# [74 rows x 3 columns]

# %%
news_df.news_category.value_counts()
# Out:
# sports        25
# world         25
# technology    24
# Name: news_category, dtype: int64
